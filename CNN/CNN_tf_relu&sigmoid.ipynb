# %% [markdown]
# # Flower Recognition CNN Keras

# %%
import os
print(os.listdir('./flowers'))
# Out:
# ['daisy', 'dandelion', 'rose', 'sunflower', 'tulip']

# %%
pip install opencv--python
# Out:
# Requirement already satisfied: opencv--python in c:\users\jk121925\anaconda3\lib\site-packages (4.5.5.62)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\jk121925\anaconda3\lib\site-packages (from opencv--python) (1.20.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# <a id="content1"></a>
# ## 1 ) Importing Various Modules.

# %%
# Ignore  the warnings
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# data visualisation and manipulation
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns
 
#configure
# sets matplotlib to inline and displays graphs below the corressponding cell.
# %matplotlib inline  
style.use('fivethirtyeight')
sns.set(style='whitegrid',color_codes=True)

#model selection
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score,precision_score,recall_score,confusion_matrix,roc_curve,roc_auc_score
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import LabelEncoder

#preprocess.
from keras.preprocessing.image import ImageDataGenerator

#dl libraraies
from keras import backend as K
from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras.optimizers import Adam,SGD,Adagrad,Adadelta,RMSprop
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import activations

# specifically for cnn
from tensorflow.keras.layers import Dropout, Flatten,Activation
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization
 
import tensorflow as tf
import random as rn

# specifically for manipulating zipped images and getting numpy arrays of pixel values of images.
import cv2                  
import numpy as np  
from tqdm import tqdm
import os                   
from random import shuffle  
from zipfile import ZipFile
from PIL import Image

# %% [markdown]
# <a id="content2"></a>
# ## 2 ) Preparing the Data

# %% [markdown]
# ## 2.1) Making the functions to get the training and validation set from the Images

# %%
X=[]
Z=[]
IMG_SIZE=150
FLOWER_DAISY_DIR='./flowers/daisy'
FLOWER_SUNFLOWER_DIR='./flowers/sunflower'
FLOWER_TULIP_DIR='./flowers/tulip'
FLOWER_DANDI_DIR='./flowers/dandelion'
FLOWER_ROSE_DIR='./flowers/rose'

# %%
def assign_label(img,flower_type):
    return flower_type

# %%
def make_train_data(flower_type,DIR):
    for img in tqdm(os.listdir(DIR)):
        label=assign_label(img,flower_type)
        path = os.path.join(DIR,img)
        img = cv2.imread(path,cv2.IMREAD_COLOR)
        img = cv2.resize(img, (IMG_SIZE,IMG_SIZE))
        
        X.append(np.array(img))
        Z.append(str(label))

# %%
make_train_data('Daisy',FLOWER_DAISY_DIR)
print(len(X))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 764/764 [00:01<00:00, 390.88it/s]
# 764

# %%
make_train_data('Sunflower',FLOWER_SUNFLOWER_DIR)
print(len(X))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 733/733 [00:02<00:00, 344.28it/s]
# 1497

# %%
make_train_data('Tulip',FLOWER_TULIP_DIR)
print(len(X))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 984/984 [00:02<00:00, 385.86it/s]
# 2481

# %%
make_train_data('Dandelion',FLOWER_DANDI_DIR)
print(len(X))
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 1052/1052 [00:02<00:00, 378.77it/s]
# 3533

# %%
make_train_data('Rose',FLOWER_ROSE_DIR)
print(len(X))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 784/784 [00:01<00:00, 406.84it/s]
# 4317

# %% [markdown]
# ## 2.2 ) Visualizing some Random Images

# %%
fig,ax=plt.subplots(5,2)
fig.set_size_inches(15,15)
for i in range(5):
    for j in range (2):
        l=rn.randint(0,len(Z))
        ax[i,j].imshow(X[l])
        ax[i,j].set_title('Flower: '+Z[l])
        
plt.tight_layout()

# %% [markdown]
# ## 2.3 ) Label Encoding the Y array (i.e. Daisy->0, Rose->1 etc...) & then One Hot Encoding

# %%
le=LabelEncoder()
Y=le.fit_transform(Z)
Y=to_categorical(Y,5)
X=np.array(X)
X=X/255

# %% [markdown]
# ## 2.4 ) Splitting into Training and Validation Sets

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.25,random_state=42)
len(x_train)
# Out:
# 3237

# %% [markdown]
# ## 2.5 ) Setting the Random Seeds

# %%
np.random.seed(42)
rn.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# <a id="content3"></a>
# ## 3 ) Modelling

# %% [markdown]
# ## 3.1 ) Building the ConvNet Model

# %%
# # modelling starts using a CNN.
#물을표를  채워주세요.!
#Hint Padding은 전부 대중적인 즉 stride가 1이라면 input과 output 사이즈를 같게 만들어주는 패딩
#Hint 커널사이즈도 대중적인 커널사이즈
#은닉충에 주로쓰는 Activation
model = Sequential()
model.add(Conv2D(filters = 32, kernel_size = (3,3),padding = "same",activation='sigmoid', input_shape = (150,150,3)))
model.add(MaxPooling2D(pool_size=(2,2)))


model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = "same",activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
 

model.add(Conv2D(filters =96, kernel_size = (3,3),padding = "same",activation ='sigmoid'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))

model.add(Conv2D(filters = 96, kernel_size = (3,3),padding = "same",activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dense(5, activation = "sigmoid")) #우리가 몇개로 분류하나요?, 다중분류에 맞는 activation

# %% [markdown]
# ## 3.2 ) Using a LR Annealer

# %%
batch_size=128
epochs=80

from keras.callbacks import ReduceLROnPlateau
red_lr= ReduceLROnPlateau(monitor='val_acc',patience=3,verbose=1,factor=0.1)

# %% [markdown]
# ## 3.3 ) Data Augmentation to prevent Overfitting

# %%
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.1, # Randomly zoom image 
        width_shift_range=0.2,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.2,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False)  # randomly flip images


datagen.fit(x_train)

# %% [markdown]
# ## 3.4 ) Compiling the Keras Model & Summary

# %%
model.compile(optimizer=Adam(lr=0.001),loss='categorical_crossentropy',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_11 (Conv2D)          (None, 150, 150, 32)      896
#
#  max_pooling2d_5 (MaxPooling  (None, 75, 75, 32)       0
#  2D)
#
#  conv2d_12 (Conv2D)          (None, 75, 75, 64)        18496
#
#  max_pooling2d_6 (MaxPooling  (None, 37, 37, 64)       0
#  2D)
#
#  conv2d_13 (Conv2D)          (None, 37, 37, 96)        55392
#
#  max_pooling2d_7 (MaxPooling  (None, 18, 18, 96)       0
#  2D)
#
#  conv2d_14 (Conv2D)          (None, 18, 18, 96)        83040
#
#  max_pooling2d_8 (MaxPooling  (None, 9, 9, 96)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 7776)              0
#
#  dense_2 (Dense)             (None, 512)               3981824
#
#  activation_1 (Activation)   (None, 512)               0
#
#  dense_3 (Dense)             (None, 5)                 2565
#
# =================================================================
# Total params: 4,142,213
# Trainable params: 4,142,213
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 3.5 ) Fitting on the Training set and making predcitons on the Validation set

# %%
History = model.fit_generator(datagen.flow(x_train,y_train, batch_size=batch_size),
                              epochs = epochs, validation_data = (x_test,y_test),
                              verbose = 1, steps_per_epoch=x_train.shape[0] // batch_size)
# model.fit(x_train,y_train,epochs=epochs,batch_size=batch_size,validation_data = (x_test,y_test))
# Out:
# Epoch 1/80
# 25/25 [==============================] - 72s 3s/step - loss: 1.8124 - accuracy: 0.2380 - val_loss: 1.6062 - val_accuracy: 0.2306
# Epoch 2/80
# 25/25 [==============================] - 68s 3s/step - loss: 1.6024 - accuracy: 0.2486 - val_loss: 1.6053 - val_accuracy: 0.2306
# Epoch 3/80
# 25/25 [==============================] - 66s 3s/step - loss: 1.5997 - accuracy: 0.2461 - val_loss: 1.6049 - val_accuracy: 0.2306
# Epoch 4/80
# 25/25 [==============================] - 64s 3s/step - loss: 1.5977 - accuracy: 0.2493 - val_loss: 1.6062 - val_accuracy: 0.2306
# Epoch 5/80
# 25/25 [==============================] - 62s 2s/step - loss: 1.5976 - accuracy: 0.2467 - val_loss: 1.6094 - val_accuracy: 0.2306
# Epoch 6/80
# 25/25 [==============================] - 63s 3s/step - loss: 1.5970 - accuracy: 0.2480 - val_loss: 1.6046 - val_accuracy: 0.2306
# Epoch 7/80
# 25/25 [==============================] - 62s 2s/step - loss: 1.5980 - accuracy: 0.2470 - val_loss: 1.6085 - val_accuracy: 0.2306
# Epoch 8/80
# 25/25 [==============================] - 64s 3s/step - loss: 1.5986 - accuracy: 0.2380 - val_loss: 1.6082 - val_accuracy: 0.2306
# Epoch 9/80
# 25/25 [==============================] - 62s 3s/step - loss: 1.5968 - accuracy: 0.2502 - val_loss: 1.6078 - val_accuracy: 0.2306
# Epoch 10/80
# 25/25 [==============================] - 63s 3s/step - loss: 1.5970 - accuracy: 0.2493 - val_loss: 1.6082 - val_accuracy: 0.2306
# Epoch 11/80
# 25/25 [==============================] - 59s 2s/step - loss: 1.5963 - accuracy: 0.2470 - val_loss: 1.6072 - val_accuracy: 0.2306
# Epoch 12/80
# 25/25 [==============================] - 63s 3s/step - loss: 1.5963 - accuracy: 0.2483 - val_loss: 1.6068 - val_accuracy: 0.2306
# Epoch 13/80
# 25/25 [==============================] - 62s 2s/step - loss: 1.5967 - accuracy: 0.2451 - val_loss: 1.6045 - val_accuracy: 0.2306
# Epoch 14/80
# 25/25 [==============================] - 62s 2s/step - loss: 1.5938 - accuracy: 0.2480 - val_loss: 1.6026 - val_accuracy: 0.2306
# Epoch 15/80
# 25/25 [==============================] - 62s 2s/step - loss: 1.5948 - accuracy: 0.2490 - val_loss: 1.6046 - val_accuracy: 0.2306
# Epoch 16/80
# 25/25 [==============================] - 62s 2s/step - loss: 1.5869 - accuracy: 0.2686 - val_loss: 1.5938 - val_accuracy: 0.2528
# Epoch 17/80
# 25/25 [==============================] - 62s 2s/step - loss: 1.5798 - accuracy: 0.2605 - val_loss: 1.5942 - val_accuracy: 0.2407
# Epoch 18/80
# 25/25 [==============================] - 62s 2s/step - loss: 1.5693 - accuracy: 0.2818 - val_loss: 1.5695 - val_accuracy: 0.2648
# Epoch 19/80
# 25/25 [==============================] - 58s 2s/step - loss: 1.5818 - accuracy: 0.2625 - val_loss: 1.5800 - val_accuracy: 0.2602
# Epoch 20/80
# 25/25 [==============================] - 58s 2s/step - loss: 1.5675 - accuracy: 0.2699 - val_loss: 1.5557 - val_accuracy: 0.2796
# Epoch 21/80
# 25/25 [==============================] - 58s 2s/step - loss: 1.5665 - accuracy: 0.2589 - val_loss: 1.5606 - val_accuracy: 0.2778
# Epoch 22/80
# 25/25 [==============================] - 58s 2s/step - loss: 1.5551 - accuracy: 0.2821 - val_loss: 1.5574 - val_accuracy: 0.2796
# Epoch 23/80
# 25/25 [==============================] - 58s 2s/step - loss: 1.5565 - accuracy: 0.2850 - val_loss: 1.5427 - val_accuracy: 0.2861
# Epoch 24/80
# 25/25 [==============================] - 64s 3s/step - loss: 1.5544 - accuracy: 0.2827 - val_loss: 1.5643 - val_accuracy: 0.2694
# Epoch 25/80
# 25/25 [==============================] - 64s 3s/step - loss: 1.5510 - accuracy: 0.2808 - val_loss: 1.5405 - val_accuracy: 0.2870
# Epoch 26/80
# 25/25 [==============================] - 63s 3s/step - loss: 1.5465 - accuracy: 0.2802 - val_loss: 1.5517 - val_accuracy: 0.2759
# Epoch 27/80
# 25/25 [==============================] - 62s 2s/step - loss: 1.5567 - accuracy: 0.2885 - val_loss: 1.5472 - val_accuracy: 0.2833
# Epoch 28/80
# 25/25 [==============================] - 63s 2s/step - loss: 1.5494 - accuracy: 0.2859 - val_loss: 1.5633 - val_accuracy: 0.2852
# Epoch 29/80
# 25/25 [==============================] - 62s 2s/step - loss: 1.5453 - accuracy: 0.2946 - val_loss: 1.5452 - val_accuracy: 0.2954
# Epoch 30/80
# 25/25 [==============================] - 63s 2s/step - loss: 1.5492 - accuracy: 0.2924 - val_loss: 1.5223 - val_accuracy: 0.3111
# Epoch 31/80
# 25/25 [==============================] - 62s 2s/step - loss: 1.5299 - accuracy: 0.3142 - val_loss: 1.5097 - val_accuracy: 0.3213
# Epoch 32/80
# 25/25 [==============================] - 63s 3s/step - loss: 1.5304 - accuracy: 0.3123 - val_loss: 1.5034 - val_accuracy: 0.3194
# Epoch 33/80
# 25/25 [==============================] - 63s 3s/step - loss: 1.5037 - accuracy: 0.3426 - val_loss: 1.4489 - val_accuracy: 0.3685
# Epoch 34/80
# 25/25 [==============================] - 67s 3s/step - loss: 1.4752 - accuracy: 0.3435 - val_loss: 1.4134 - val_accuracy: 0.3935
# Epoch 35/80
# 25/25 [==============================] - 66s 3s/step - loss: 1.4469 - accuracy: 0.3744 - val_loss: 1.4111 - val_accuracy: 0.4157
# Epoch 36/80
# 25/25 [==============================] - 63s 3s/step - loss: 1.4192 - accuracy: 0.3792 - val_loss: 1.3200 - val_accuracy: 0.4241
# Epoch 37/80
# 25/25 [==============================] - 59s 2s/step - loss: 1.3872 - accuracy: 0.3956 - val_loss: 1.3214 - val_accuracy: 0.4241
# Epoch 38/80
# 25/25 [==============================] - 57s 2s/step - loss: 1.3670 - accuracy: 0.4117 - val_loss: 1.2933 - val_accuracy: 0.4333
# Epoch 39/80
# 25/25 [==============================] - 58s 2s/step - loss: 1.3427 - accuracy: 0.4294 - val_loss: 1.2432 - val_accuracy: 0.4583
# Epoch 40/80
# 25/25 [==============================] - 59s 2s/step - loss: 1.2873 - accuracy: 0.4588 - val_loss: 1.2346 - val_accuracy: 0.4657
# Epoch 41/80
# 25/25 [==============================] - 58s 2s/step - loss: 1.2473 - accuracy: 0.4744 - val_loss: 1.1739 - val_accuracy: 0.5204
# Epoch 42/80
# 25/25 [==============================] - 59s 2s/step - loss: 1.2058 - accuracy: 0.4979 - val_loss: 1.1306 - val_accuracy: 0.5472
# Epoch 43/80
# 25/25 [==============================] - 65s 3s/step - loss: 1.1943 - accuracy: 0.5053 - val_loss: 1.2018 - val_accuracy: 0.4991
# Epoch 44/80
# 25/25 [==============================] - 66s 3s/step - loss: 1.1568 - accuracy: 0.5236 - val_loss: 1.0882 - val_accuracy: 0.5630
# Epoch 45/80
# 25/25 [==============================] - 65s 3s/step - loss: 1.1492 - accuracy: 0.5265 - val_loss: 1.1410 - val_accuracy: 0.5435
# Epoch 46/80
# 25/25 [==============================] - 61s 2s/step - loss: 1.1452 - accuracy: 0.5417 - val_loss: 1.1497 - val_accuracy: 0.5426
# Epoch 47/80
# 25/25 [==============================] - 59s 2s/step - loss: 1.1065 - accuracy: 0.5552 - val_loss: 1.0741 - val_accuracy: 0.5565
# Epoch 48/80
# 25/25 [==============================] - 58s 2s/step - loss: 1.1023 - accuracy: 0.5635 - val_loss: 1.0490 - val_accuracy: 0.5861
# Epoch 49/80
# 25/25 [==============================] - 58s 2s/step - loss: 1.0711 - accuracy: 0.5683 - val_loss: 1.0385 - val_accuracy: 0.5750
# Epoch 50/80
# 25/25 [==============================] - 57s 2s/step - loss: 1.0540 - accuracy: 0.5819 - val_loss: 1.0203 - val_accuracy: 0.5759
# Epoch 51/80
# 25/25 [==============================] - 58s 2s/step - loss: 1.0303 - accuracy: 0.5899 - val_loss: 0.9608 - val_accuracy: 0.6111
# Epoch 52/80
# 25/25 [==============================] - 61s 2s/step - loss: 1.0524 - accuracy: 0.5774 - val_loss: 1.0148 - val_accuracy: 0.5824
# Epoch 53/80
# 25/25 [==============================] - 59s 2s/step - loss: 1.0277 - accuracy: 0.5970 - val_loss: 0.9808 - val_accuracy: 0.6028
# Epoch 54/80
# 25/25 [==============================] - 59s 2s/step - loss: 0.9997 - accuracy: 0.6108 - val_loss: 0.9535 - val_accuracy: 0.6130
# Epoch 55/80
# 25/25 [==============================] - 59s 2s/step - loss: 1.0227 - accuracy: 0.5928 - val_loss: 0.9739 - val_accuracy: 0.6185
# Epoch 56/80
# 25/25 [==============================] - 59s 2s/step - loss: 0.9946 - accuracy: 0.6127 - val_loss: 0.9701 - val_accuracy: 0.6056
# Epoch 57/80
# 25/25 [==============================] - 59s 2s/step - loss: 1.0186 - accuracy: 0.5915 - val_loss: 0.9548 - val_accuracy: 0.6139
# Epoch 58/80
# 25/25 [==============================] - 59s 2s/step - loss: 0.9752 - accuracy: 0.6150 - val_loss: 0.9324 - val_accuracy: 0.6204
# Epoch 59/80
# 25/25 [==============================] - 60s 2s/step - loss: 0.9472 - accuracy: 0.6384 - val_loss: 0.9315 - val_accuracy: 0.6259
# Epoch 60/80
# 25/25 [==============================] - 59s 2s/step - loss: 0.9585 - accuracy: 0.6359 - val_loss: 0.9730 - val_accuracy: 0.6074
# Epoch 61/80
# 25/25 [==============================] - 59s 2s/step - loss: 0.9418 - accuracy: 0.6314 - val_loss: 0.9171 - val_accuracy: 0.6417
# Epoch 62/80
# 25/25 [==============================] - 59s 2s/step - loss: 0.9433 - accuracy: 0.6340 - val_loss: 0.8964 - val_accuracy: 0.6343
# Epoch 63/80
# 25/25 [==============================] - 59s 2s/step - loss: 0.9497 - accuracy: 0.6301 - val_loss: 0.9202 - val_accuracy: 0.6213
# Epoch 64/80
# 25/25 [==============================] - 59s 2s/step - loss: 0.9254 - accuracy: 0.6443 - val_loss: 0.9189 - val_accuracy: 0.6287
# Epoch 65/80
# 25/25 [==============================] - 59s 2s/step - loss: 0.9368 - accuracy: 0.6340 - val_loss: 0.9154 - val_accuracy: 0.6454
# Epoch 66/80
# 25/25 [==============================] - 59s 2s/step - loss: 0.9144 - accuracy: 0.6481 - val_loss: 0.8805 - val_accuracy: 0.6472
# Epoch 67/80
# 25/25 [==============================] - 59s 2s/step - loss: 0.8988 - accuracy: 0.6562 - val_loss: 0.8840 - val_accuracy: 0.6380
# Epoch 68/80
# 25/25 [==============================] - 59s 2s/step - loss: 0.8837 - accuracy: 0.6520 - val_loss: 0.8838 - val_accuracy: 0.6444
# Epoch 69/80
# 25/25 [==============================] - 59s 2s/step - loss: 0.8822 - accuracy: 0.6610 - val_loss: 0.8917 - val_accuracy: 0.6546
# Epoch 70/80
# 25/25 [==============================] - 61s 2s/step - loss: 0.8733 - accuracy: 0.6639 - val_loss: 0.8471 - val_accuracy: 0.6611
# Epoch 71/80
# 25/25 [==============================] - 57s 2s/step - loss: 0.8704 - accuracy: 0.6607 - val_loss: 0.8452 - val_accuracy: 0.6556
# Epoch 72/80
# 25/25 [==============================] - 57s 2s/step - loss: 0.8499 - accuracy: 0.6758 - val_loss: 0.8566 - val_accuracy: 0.6731
# Epoch 73/80
# 25/25 [==============================] - 62s 2s/step - loss: 0.8569 - accuracy: 0.6681 - val_loss: 0.9094 - val_accuracy: 0.6556
# Epoch 74/80
# 25/25 [==============================] - 62s 2s/step - loss: 0.8629 - accuracy: 0.6600 - val_loss: 0.8524 - val_accuracy: 0.6685
# Epoch 75/80
# 25/25 [==============================] - 61s 2s/step - loss: 0.8249 - accuracy: 0.6854 - val_loss: 0.8424 - val_accuracy: 0.6639
# Epoch 76/80
# 25/25 [==============================] - 62s 2s/step - loss: 0.8345 - accuracy: 0.6767 - val_loss: 0.8488 - val_accuracy: 0.6676
# Epoch 77/80
# 25/25 [==============================] - 63s 3s/step - loss: 0.8123 - accuracy: 0.6870 - val_loss: 0.8308 - val_accuracy: 0.6796
# Epoch 78/80
# 25/25 [==============================] - 63s 2s/step - loss: 0.8257 - accuracy: 0.6722 - val_loss: 0.8334 - val_accuracy: 0.6713
# Epoch 79/80
# 25/25 [==============================] - 58s 2s/step - loss: 0.8078 - accuracy: 0.6909 - val_loss: 0.8232 - val_accuracy: 0.6685
# Epoch 80/80
# 25/25 [==============================] - 58s 2s/step - loss: 0.8003 - accuracy: 0.6938 - val_loss: 0.8240 - val_accuracy: 0.6806

# %% [markdown]
# <a id="content4"></a>
# ## 4 ) Evaluating the Model Performance

# %%
plt.plot(History.history['loss'])
plt.plot(History.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()

# %%
plt.plot(History.history['accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()

# %% [markdown]
# #### CORRECTLY CLASSIFIED FLOWER IMAGES

# %% [markdown]
# #  THE END.
